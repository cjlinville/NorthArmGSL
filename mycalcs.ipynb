# %%
import pandas as pd

# %%
mass_balance_path = "mass_balance.csv"
df = pd.read_csv(mass_balance_path)
print(df.columns)
# Out:
# Index(['Month', 'Level as of 1st', 'Change in Lake Level ft',
#        'Precipitation(Inches)', 'Precipitation (ft)',
#        'Evaporation (Mass Balance)'],
#       dtype='str')

# %%
#lets calculate the observed volume change
df.columns=['date','elev','dz','precip(in)','precip(ft)','loss']
df['observed_dv'] =

# %%
#dv = (precip * surface area) + inputs - evaporation - outflow
